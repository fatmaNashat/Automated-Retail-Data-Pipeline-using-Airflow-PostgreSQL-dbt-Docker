# %%
# %pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('../data/raw/Walmart.csv')
print(df)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
import os
os.makedirs('../data/bronze', exist_ok=True)

# %%
import sys
# !{sys.executable} -m pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (2026.3.0)
# Requirement already satisfied: pandas>=1.5.0 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from fastparquet) (2.3.3)
# Requirement already satisfied: numpy in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from fastparquet) (2.2.6)
# Requirement already satisfied: cramjam>=2.3 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from fastparquet) (2026.3.0)
# Requirement already satisfied: packaging in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from fastparquet) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from pandas>=1.5.0->fastparquet) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from pandas>=1.5.0->fastparquet) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)

# %%
import os
os.makedirs('../data/bronze/', exist_ok=True)

df.to_parquet('../data/bronze/Walmart.parquet', index=False, engine='fastparquet')

# %%
# %pip install SQLAlchemy
# Out:
# Requirement already satisfied: SQLAlchemy in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (2.0.49)
# Requirement already satisfied: greenlet>=1 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from SQLAlchemy) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\fatma\depi\final_project\project\dbt-env\lib\site-packages (from SQLAlchemy) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine, text
engine = create_engine('postgresql://postgres:123@localhost:5432/retail_db')

with engine.connect() as conn:
    trans = conn.begin()
    conn.execute(text("TRUNCATE TABLE raw.walmart_sales"))
    trans.commit()

# %%
df.to_sql("walmart_sales", engine, schema="raw", if_exists="append", index=False)

print(f"Successfully loaded {len(df)} rows.")
# Out:
# Successfully loaded 6435 rows.
