# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [2]</a>'.</span>

# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
df = pd.read_csv('../data/raw/Walmart.csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('../data/raw/Walmart.csv')
#       2 print(df)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
# ...

# %%
import os
os.makedirs('../data/bronze', exist_ok=True)

# %%
import sys
# !{sys.executable} -m pip install fastparquet

# %%
import os
os.makedirs('../data/bronze/', exist_ok=True)

df.to_parquet('../data/bronze/Walmart.parquet', index=False, engine='fastparquet')

# %%
# %pip install SQLAlchemy

# %%
from sqlalchemy import create_engine, text
engine = create_engine('postgresql://postgres:123@localhost:5432/retail_db')

with engine.connect() as conn:
    trans = conn.begin()
    conn.execute(text("TRUNCATE TABLE raw.walmart_sales"))
    trans.commit()

# %%
df.to_sql("walmart_sales", engine, schema="raw", if_exists="append", index=False)

print(f"Successfully loaded {len(df)} rows.")
